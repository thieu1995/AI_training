# %%
from PSO_func import *
import matplotlib.pyplot as plt
import operator
import time
# %matplotlib inline

# %%
sample = PSO(size_pop = 200, size_var = 50, constraints = [-10, 10])

# %%
start = time.clock()
min_size = sample.run(2000)
Run_time = time.clock() - start
# Out:
# /home/tien/Python/Minhnb_lab/ha_viet_tien/week2_PSO/PSO_func.py:116: RuntimeWarning: overflow encountered in multiply
#   c1*r1*(self.Pposition[i] - self.pop[i]) + \

# %%
min(min_size)
# Out:
# array(-20.54022542)

# %%
Run_time/2000
# Out:
# 0.039500201000000006

# %%
plt.figure(figsize = [20,10])
plt.title("Particle Swarm Optimization" )
plt.ylim(bottom = -25, top = 25)
plt.plot(min_size[:20])
plt.savefig("result/four_clusterPSO.png")

# %% [markdown]
# In here i chose c1 and c2 using following func:
# # C = (Cmin - Cmax)*(iteration_now/iteration_sum) + Cmax
# And with:
# # w = c1*r1 + c2*r2

# %% [markdown]
# And here is with:
# # w(t+1) = (w(t) - 0.4)(iteration_sum-iteration_now) / (iteration_sum+0.4)
